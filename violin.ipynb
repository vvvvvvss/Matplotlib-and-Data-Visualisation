# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(10)
collectn_1 = np.random.normal(100, 10, 200)

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

plt.violinplot(collectn_1,vert=True)
plt.title('Violin plot')
plt.savefig("violin.png")
